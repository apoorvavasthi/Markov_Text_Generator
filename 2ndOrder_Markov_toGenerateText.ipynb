# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split

# %%
initial = {} # start of a phrase
first_order = {} # second word only
second_order = {}

# %%
def remove_punctuation(s):
    return s.translate(str.maketrans('','',string.punctuation))

# %%
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2024-07-30 15:13:37--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54.97K  --.-KB/s    in 0.01s
#
# 2024-07-30 15:13:38 (4.48 MB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
def add2dict(d, k, v):
  if k not in d:
    d[k] = []
  d[k].append(v)

# %%
for line in open('robert_frost.txt'):
  tokens = remove_punctuation(line.rstrip().lower()).split()

  T = len(tokens)
  for i in range(T):
    t = tokens[i]
    if i == 0:
      # measure the distribution of the first word
      initial[t] = initial.get(t, 0.) + 1
    else:
      t_1 = tokens[i-1]
      if i == T - 1:
        # measure probability of ending the line
        add2dict(second_order, (t_1, t), 'END')
      if i == 1:
        # measure distribution of second word
        # given only first word
        add2dict(first_order, t_1, t)
      else:
        t_2 = tokens[i-2]
        add2dict(second_order, (t_2, t_1), t)

# %%
# normalize the distributions
initial_total = sum(initial.values())
for t, c in initial.items():
    initial[t] = c / initial_total

# %%
initial
# Out:
# {'two': 0.005571030640668524,
#  'and': 0.08983286908077995,
#  'to': 0.034818941504178275,
#  'then': 0.008356545961002786,
#  'because': 0.0006963788300835655,
#  'though': 0.004874651810584958,
#  'had': 0.002785515320334262,
#  'in': 0.0201949860724234,
#  'oh': 0.002785515320334262,
#  'yet': 0.0020891364902506965,
#  'i': 0.08217270194986072,
#  'somewhere': 0.0006963788300835655,
#  'whose': 0.001392757660167131,
#  'his': 0.004874651810584958,
#  'he': 0.023676880222841225,
#  'my': 0.004874651810584958,
#  'between': 0.0020891364902506965,
#  'the': 0.057103064066852366,
#  'of': 0.0201949860724234,
#  'but': 0.035515320334261836,
#  'some': 0.003481894150417827,
#  'from': 0.006963788300835654,
#  'is': 0.003481894150417827,
#  'natures': 0.0006963788300835655,
#  'her': 0.001392757660167131,
#  'so': 0.009052924791086351,
#  'nothing': 0.001392757660167131,
#  'when': 0.006267409470752089,
#  'came': 0.0006963788300835655,
#  'one': 0.00766016713091922,
#  'proclaimed': 0.0006963788300835655,
#  'smoothlaid': 0.0006963788300835655,
#  'half': 0.0020891364902506965,
#  'up': 0.004874651810584958,
#  'a': 0.020891364902506964,
#  'disturbed': 0.001392757660167131,
#  'comes': 0.0006963788300835655,
#  'by': 0.00766016713091922,
#  'if': 0.008356545961002786,
#  'were': 0.0020891364902506965,
#  'ten': 0.0006963788300835655,
#  'as': 0.009749303621169917,
#  'it': 0.016016713091922007,
#  'lifted': 0.0006963788300835655,
#  'she': 0.011838440111420613,
#  'transfixed': 0.0006963788300835655,
#  'across': 0.0006963788300835655,
#  'was': 0.006267409470752089,
#  'once': 0.001392757660167131,
#  'that': 0.0201949860724234,
#  'looked': 0.0006963788300835655,
#  'stood': 0.0006963788300835655,
#  'you': 0.027855153203342618,
#  'me': 0.0006963788300835655,
#  'sometimes': 0.002785515320334262,
#  'brown': 0.001392757660167131,
#  'cross': 0.0006963788300835655,
#  'describing': 0.0006963788300835655,
#  'got': 0.0006963788300835655,
#  'walls': 0.0006963788300835655,
#  'like': 0.005571030640668524,
#  'upon': 0.001392757660167131,
#  'with': 0.012534818941504178,
#  'faster': 0.0006963788300835655,
#  'sitting': 0.0006963788300835655,
#  'according': 0.0006963788300835655,
#  'hes': 0.00766016713091922,
#  'or': 0.00766016713091922,
#  'incredulous': 0.0006963788300835655,
#  'well—i—be—': 0.0006963788300835655,
#  'on': 0.00766016713091922,
#  'should': 0.001392757660167131,
#  'yankees': 0.0006963788300835655,
#  'dont': 0.004874651810584958,
#  'until': 0.001392757660167131,
#  'after': 0.0006963788300835655,
#  'not': 0.009052924791086351,
#  'at': 0.004178272980501393,
#  'no': 0.009052924791086351,
#  'ive': 0.002785515320334262,
#  'while': 0.0006963788300835655,
#  'bout': 0.0006963788300835655,
#  'now': 0.002785515320334262,
#  'im': 0.003481894150417827,
#  'theyve': 0.0006963788300835655,
#  'flattered': 0.0006963788300835655,
#  'they': 0.013231197771587743,
#  'always': 0.0006963788300835655,
#  'ill': 0.006963788300835654,
#  'theyll': 0.0006963788300835655,
#  'for': 0.004874651810584958,
#  'couldnt': 0.001392757660167131,
#  'voted': 0.0006963788300835655,
#  'which': 0.0020891364902506965,
#  'their': 0.001392757660167131,
#  'wentworth': 0.0006963788300835655,
#  'only': 0.003481894150417827,
#  'rights': 0.0006963788300835655,
#  'has': 0.001392757660167131,
#  'itd': 0.0006963788300835655,
#  'said': 0.0006963788300835655,
#  'hed': 0.003481894150417827,
#  'all': 0.005571030640668524,
#  'gnaws': 0.0006963788300835655,
#  'last': 0.0006963788300835655,
#  'over': 0.003481894150417827,
#  'well': 0.003481894150417827,
#  'off': 0.001392757660167131,
#  'old': 0.001392757660167131,
#  'thered': 0.0006963788300835655,
#  'someday': 0.0006963788300835655,
#  'today': 0.0006963788300835655,
#  'huh': 0.0006963788300835655,
#  'lets': 0.0020891364902506965,
#  'youve': 0.0006963788300835655,
#  'can': 0.0006963788300835655,
#  'be': 0.0020891364902506965,
#  'we': 0.010445682451253482,
#  'ascending': 0.0006963788300835655,
#  'sos': 0.001392757660167131,
#  'hadnt': 0.0006963788300835655,
#  'look': 0.0006963788300835655,
#  'what': 0.009749303621169917,
#  'however': 0.001392757660167131,
#  'come': 0.002785515320334262,
#  'its': 0.014623955431754874,
#  'perhaps': 0.001392757660167131,
#  'excuse': 0.0006963788300835655,
#  'who': 0.004178272980501393,
#  'life': 0.0006963788300835655,
#  'our': 0.001392757660167131,
#  'through': 0.001392757660167131,
#  'except': 0.001392757660167131,
#  'books': 0.001392757660167131,
#  'where': 0.005571030640668524,
#  'enough': 0.0006963788300835655,
#  'unfortunately': 0.0006963788300835655,
#  'boys': 0.0006963788300835655,
#  'shatter': 0.0006963788300835655,
#  'how': 0.004178272980501393,
#  'till': 0.001392757660167131,
#  'tried': 0.0006963788300835655,
#  'having': 0.0006963788300835655,
#  'here': 0.002785515320334262,
#  'take': 0.0020891364902506965,
#  'why': 0.0020891364902506965,
#  'goodlooking': 0.0006963788300835655,
#  'both': 0.0006963788300835655,
#  'legitimately': 0.0006963788300835655,
#  'there': 0.004178272980501393,
#  'crosslegged': 0.0006963788300835655,
#  'alias': 0.0006963788300835655,
#  'about': 0.0006963788300835655,
#  'theres': 0.0006963788300835655,
#  'give': 0.0006963788300835655,
#  'thrown': 0.0006963788300835655,
#  'unless': 0.0006963788300835655,
#  'than': 0.001392757660167131,
#  'behind': 0.001392757660167131,
#  'mother': 0.004874651810584958,
#  'summoning': 0.0006963788300835655,
#  'whos': 0.0006963788300835655,
#  'son': 0.006267409470752089,
#  'done': 0.0006963788300835655,
#  'rather': 0.0006963788300835655,
#  'tell': 0.001392757660167131,
#  'yes': 0.005571030640668524,
#  'against': 0.0006963788300835655,
#  'halting': 0.0006963788300835655,
#  'never': 0.0006963788300835655,
#  'another': 0.001392757660167131,
#  'right': 0.0006963788300835655,
#  'father': 0.0006963788300835655,
#  'especially': 0.0006963788300835655,
#  'might': 0.0006963788300835655,
#  'toffile': 0.003481894150417827,
#  'struck': 0.0006963788300835655,
#  'began': 0.0006963788300835655,
#  'waiting': 0.0006963788300835655,
#  'flashed': 0.0006963788300835655,
#  'smoke': 0.0006963788300835655,
#  'hand': 0.0006963788300835655,
#  'stillgoing': 0.0006963788300835655,
#  'before': 0.001392757660167131,
#  'almost': 0.0006963788300835655,
#  'quick': 0.0006963788300835655,
#  'let': 0.001392757660167131,
#  'brushing': 0.0006963788300835655,
#  'thats': 0.003481894150417827,
#  '2o3': 0.0006963788300835655,
#  'wed': 0.0006963788300835655,
#  'could': 0.0006963788300835655,
#  'among': 0.0020891364902506965,
#  'ancestral': 0.0006963788300835655,
#  'someone': 0.0006963788300835655,
#  'thence': 0.0006963788300835655,
#  'made': 0.0006963788300835655,
#  'are': 0.0006963788300835655,
#  'strolled': 0.0006963788300835655,
#  'anyone': 0.001392757660167131,
#  'this': 0.004178272980501393,
#  'provision': 0.0006963788300835655,
#  'drawn': 0.001392757660167131,
#  'stark': 0.0006963788300835655,
#  'would': 0.001392757660167131,
#  'several': 0.0006963788300835655,
#  'under': 0.001392757660167131,
#  'just': 0.0006963788300835655,
#  'does': 0.001392757660167131,
#  'bowed': 0.0006963788300835655,
#  'beyond': 0.001392757660167131,
#  'four': 0.0006963788300835655,
#  'dyou': 0.0006963788300835655,
#  'studying': 0.0006963788300835655,
#  'first': 0.001392757660167131,
#  'bless': 0.001392757660167131,
#  'shes': 0.0020891364902506965,
#  'heres': 0.0006963788300835655,
#  'making': 0.0006963788300835655,
#  'see': 0.0006963788300835655,
#  'strung': 0.0006963788300835655,
#  'something': 0.001392757660167131,
#  'speaking': 0.0006963788300835655,
#  'strangely': 0.0006963788300835655,
#  'call': 0.001392757660167131,
#  'nor': 0.002785515320334262,
#  'nine': 0.0006963788300835655,
#  'anything': 0.0006963788300835655,
#  'folks': 0.0006963788300835655,
#  'mebbe': 0.0006963788300835655,
#  'more': 0.0006963788300835655,
#  'will': 0.001392757660167131,
#  'nowhere': 0.0006963788300835655,
#  'builder': 0.0006963788300835655,
#  'whatever': 0.0006963788300835655,
#  'inscription': 0.0006963788300835655,
#  'winds': 0.0006963788300835655,
#  'moisture': 0.0006963788300835655,
#  'heaven': 0.0006963788300835655,
#  'back': 0.001392757660167131,
#  'may': 0.0006963788300835655,
#  'great': 0.0006963788300835655,
#  'long': 0.0006963788300835655,
#  'besides': 0.0006963788300835655,
#  'still': 0.001392757660167131,
#  'charge': 0.0006963788300835655,
#  'make': 0.001392757660167131,
#  'someones': 0.0006963788300835655,
#  'into': 0.0006963788300835655,
#  'weep': 0.0006963788300835655,
#  'your': 0.0006963788300835655,
#  'cold': 0.0006963788300835655,
#  'too': 0.001392757660167131,
#  'drink': 0.0006963788300835655,
#  'wherever': 0.0006963788300835655,
#  'birch': 0.0006963788300835655,
#  'time': 0.0006963788300835655,
#  'small': 0.0006963788300835655,
#  'out': 0.0006963788300835655,
#  'awake': 0.0006963788300835655,
#  'wishing': 0.0006963788300835655,
#  'saturn': 0.0006963788300835655,
#  'speculation': 0.0006963788300835655,
#  'theirs': 0.0006963788300835655,
#  'uttered': 0.0006963788300835655,
#  'trembled': 0.0006963788300835655,
#  'appear': 0.0006963788300835655,
#  'around': 0.0006963788300835655,
#  'since': 0.0006963788300835655,
#  'lord': 0.0006963788300835655,
#  'havent': 0.001392757660167131,
#  'whats': 0.002785515320334262,
#  'estelles': 0.001392757660167131,
#  'weve': 0.0006963788300835655,
#  'left': 0.0006963788300835655,
#  'hell': 0.0006963788300835655,
#  'skyhigh': 0.0006963788300835655,
#  'arent': 0.0006963788300835655,
#  'john': 0.004178272980501393,
#  'better': 0.0006963788300835655,
#  'reason': 0.0006963788300835655,
#  'such': 0.0006963788300835655,
#  'twas': 0.0006963788300835655,
#  'johns': 0.001392757660167131,
#  'estelle': 0.0006963788300835655,
#  'farmers': 0.0006963788300835655,
#  'full': 0.0006963788300835655,
#  'moving': 0.0006963788300835655,
#  'nothings': 0.0006963788300835655,
#  'twenty': 0.0006963788300835655,
#  'receipted': 0.0006963788300835655,
#  'wampum': 0.0006963788300835655,
#  'cant': 0.0006963788300835655,
#  'being': 0.0006963788300835655,
#  'oho': 0.0006963788300835655,
#  'bad': 0.0006963788300835655,
#  'nonsense': 0.0006963788300835655,
#  'whod': 0.0006963788300835655,
#  'say': 0.0006963788300835655,
#  'youll': 0.0006963788300835655,
#  'coming': 0.0006963788300835655,
#  'isnt': 0.0006963788300835655,
#  'do': 0.0006963788300835655,
#  'content': 0.0006963788300835655,
#  'an': 0.0006963788300835655}

# %%
def list2pdict(ts):
  # turn each list of possibilities into a dictionary of probabilities
  d = {}
  n = len(ts)
  for t in ts:
    d[t] = d.get(t, 0.) + 1
  for t, c in d.items():
    d[t] = c / n
  return d

# %%
for t_1, ts in first_order.items():
  # replace list with dictionary of probabilities
  first_order[t_1] = list2pdict(ts)

# %%
first_order
# Out:
# {'two': {'roads': 0.14285714285714285,
#   'miles': 0.14285714285714285,
#   'oldbelievers': 0.14285714285714285,
#   'winds': 0.14285714285714285,
#   'weeks': 0.14285714285714285,
#   'of': 0.14285714285714285,
#   'at': 0.14285714285714285},
#  'and': {'sorry': 0.009708737864077669,
#   'be': 0.009708737864077669,
#   'looked': 0.009708737864077669,
#   'having': 0.009708737864077669,
#   'both': 0.009708737864077669,
#   'that': 0.009708737864077669,
#   'miles': 0.009708737864077669,
#   'would': 0.009708737864077669,
#   'dropped': 0.009708737864077669,
#   'further': 0.009708737864077669,
#   'when': 0.009708737864077669,
#   'tell': 0.009708737864077669,
#   'the': 0.009708737864077669,
#   'caught': 0.009708737864077669,
#   'put': 0.009708737864077669,
#   'threw': 0.009708737864077669,
#   'birds': 0.009708737864077669,
#   'suddenly': 0.009708737864077669,
#   'scurf': 0.009708737864077669,
#   'since': 0.009708737864077669,
#   'whats': 0.009708737864077669,
#   'many': 0.009708737864077669,
#   'blew': 0.009708737864077669,
#   'stamped': 0.009708737864077669,
#   'sometimes': 0.009708737864077669,
#   'some': 0.009708737864077669,
#   'then': 0.009708737864077669,
#   'came': 0.009708737864077669,
#   'this': 0.009708737864077669,
#   'politician': 0.009708737864077669,
#   'thatd': 0.009708737864077669,
#   'rode': 0.009708737864077669,
#   'if': 0.009708737864077669,
#   'from': 0.009708737864077669,
#   'i': 0.009708737864077669,
#   'he': 0.009708737864077669,
#   'full': 0.009708737864077669,
#   'experts': 0.009708737864077669,
#   'built': 0.009708737864077669,
#   'thats': 0.009708737864077669,
#   'spoke': 0.009708737864077669,
#   'anyway': 0.009708737864077669,
#   'had': 0.009708737864077669,
#   'how': 0.009708737864077669,
#   'taken': 0.009708737864077669,
#   'lie': 0.009708737864077669,
#   'left': 0.009708737864077669,
#   'stroked': 0.009708737864077669,
#   'a': 0.009708737864077669,
#   'me': 0.009708737864077669,
#   'between': 0.009708737864077669,
#   'wont': 0.009708737864077669,
#   'hes': 0.009708737864077669,
#   'his': 0.009708737864077669,
#   'nothing': 0.009708737864077669,
#   'better': 0.009708737864077669,
#   'kick': 0.009708737864077669,
#   'carried': 0.009708737864077669,
#   'thought': 0.009708737864077669,
#   'swollen': 0.009708737864077669,
#   'hold': 0.009708737864077669,
#   'all': 0.009708737864077669,
#   'fell': 0.009708737864077669,
#   'set': 0.009708737864077669,
#   'sit': 0.009708737864077669,
#   'bring': 0.009708737864077669,
#   'push': 0.009708737864077669,
#   'those': 0.009708737864077669,
#   'sproutlands': 0.009708737864077669,
#   'perhaps': 0.009708737864077669,
#   'see': 0.009708737864077669,
#   'dangle': 0.009708737864077669,
#   'disappeared': 0.009708737864077669,
#   'below': 0.009708737864077669,
#   'what': 0.009708737864077669,
#   'come': 0.009708737864077669,
#   'begin': 0.009708737864077669,
#   'build': 0.009708737864077669,
#   'in': 0.009708737864077669,
#   'theres': 0.009708737864077669,
#   'stifling': 0.009708737864077669,
#   'got': 0.009708737864077669,
#   'lift': 0.009708737864077669,
#   'give': 0.009708737864077669,
#   'fight': 0.009708737864077669,
#   'such': 0.009708737864077669,
#   'moon': 0.009708737864077669,
#   'jupiter': 0.009708737864077669,
#   'save': 0.009708737864077669,
#   'nation': 0.009708737864077669,
#   'though': 0.009708737864077669,
#   'now': 0.009708737864077669,
#   'wheres': 0.009708737864077669,
#   'shell': 0.009708737864077669,
#   'no': 0.009708737864077669,
#   'end': 0.009708737864077669,
#   'after': 0.009708737864077669,
#   'we': 0.009708737864077669,
#   'like': 0.009708737864077669,
#   'youre': 0.009708737864077669,
#   'turn': 0.009708737864077669,
#   'not': 0.009708737864077669,
#   'last': 0.009708737864077669},
#  'to': {'where': 0.02631578947368421,
#   'watch': 0.02631578947368421,
#   'stop': 0.02631578947368421,
#   'ask': 0.02631578947368421,
#   'say': 0.02631578947368421,
#   'carry': 0.02631578947368421,
#   'think': 0.02631578947368421,
#   'make': 0.02631578947368421,
#   'everything': 0.02631578947368421,
#   'spare': 0.02631578947368421,
#   'see': 0.02631578947368421,
#   'turn': 0.02631578947368421,
#   'undo': 0.02631578947368421,
#   'let': 0.02631578947368421,
#   'go': 0.02631578947368421,
#   'shut': 0.02631578947368421,
#   'bring': 0.02631578947368421,
#   'entertain': 0.02631578947368421,
#   'find': 0.02631578947368421,
#   'send': 0.02631578947368421,
#   'such': 0.02631578947368421,
#   'wonder': 0.02631578947368421,
#   'no': 0.02631578947368421,
#   'tell': 0.02631578947368421,
#   'stand': 0.02631578947368421,
#   'reconnoitre': 0.02631578947368421,
#   'set': 0.02631578947368421,
#   'blow': 0.02631578947368421,
#   'ridgely': 0.02631578947368421,
#   'the': 0.02631578947368421,
#   'curl': 0.02631578947368421,
#   'call': 0.02631578947368421,
#   'which': 0.02631578947368421,
#   'be': 0.02631578947368421,
#   'drag': 0.02631578947368421,
#   'come': 0.02631578947368421,
#   'live': 0.02631578947368421,
#   'break': 0.02631578947368421},
#  'then': {'took': 0.08333333333333333,
#   'leaf': 0.08333333333333333,
#   'shook': 0.08333333333333333,
#   'that': 0.08333333333333333,
#   'he': 0.08333333333333333,
#   'ran': 0.08333333333333333,
#   'we': 0.08333333333333333,
#   'i': 0.08333333333333333,
#   'make': 0.08333333333333333,
#   'for': 0.08333333333333333,
#   'cane': 0.08333333333333333,
#   'its': 0.08333333333333333},
#  'because': {'it': 1.0},
#  'though': {'as': 0.16666666666666666,
#   'slight': 0.16666666666666666,
#   'what': 0.16666666666666666,
#   'not': 0.16666666666666666,
#   'strange': 0.16666666666666666,
#   'set': 0.16666666666666666},
#  'had': {'worn': 0.25, 'spilled': 0.25, 'been': 0.25, 'checked': 0.25},
#  'in': {'leaves': 0.043478260869565216,
#   'front': 0.043478260869565216,
#   'the': 0.043478260869565216,
#   'every': 0.043478260869565216,
#   'winter': 0.043478260869565216,
#   'warren': 0.043478260869565216,
#   'wentworth': 0.043478260869565216,
#   'dalton': 0.043478260869565216,
#   'eightyfive': 0.043478260869565216,
#   'dust': 0.043478260869565216,
#   'virgin': 0.043478260869565216,
#   'time': 0.043478260869565216,
#   'one': 0.043478260869565216,
#   'snow': 0.043478260869565216,
#   'its': 0.043478260869565216,
#   'summer': 0.043478260869565216,
#   'going': 0.043478260869565216,
#   'an': 0.043478260869565216,
#   'a': 0.043478260869565216,
#   'rain': 0.043478260869565216,
#   'that': 0.043478260869565216,
#   'separate': 0.043478260869565216,
#   'ways': 0.043478260869565216},
#  'oh': {'i': 0.3333333333333333,
#   'if': 0.3333333333333333,
#   'thats': 0.3333333333333333},
#  'yet': {'knowing': 0.3333333333333333,
#   'oh': 0.3333333333333333,
#   'does': 0.3333333333333333},
#  'i': {'doubted': 0.016666666666666666,
#   'shall': 0.016666666666666666,
#   'took': 0.016666666666666666,
#   'hold': 0.016666666666666666,
#   'think': 0.016666666666666666,
#   'have': 0.016666666666666666,
#   'end': 0.016666666666666666,
#   'cant': 0.016666666666666666,
#   'fancied': 0.016666666666666666,
#   'looked': 0.016666666666666666,
#   'was': 0.016666666666666666,
#   'paused': 0.016666666666666666,
#   'saw': 0.016666666666666666,
#   'wonder': 0.016666666666666666,
#   'could': 0.016666666666666666,
#   'guess': 0.016666666666666666,
#   'know': 0.016666666666666666,
#   'made': 0.016666666666666666,
#   'hope': 0.016666666666666666,
#   'might': 0.016666666666666666,
#   'thought': 0.016666666666666666,
#   'am': 0.016666666666666666,
#   'wont': 0.016666666666666666,
#   'want': 0.016666666666666666,
#   'vow': 0.016666666666666666,
#   'didnt': 0.016666666666666666,
#   'never': 0.016666666666666666,
#   'stay': 0.016666666666666666,
#   'can': 0.016666666666666666,
#   'staid': 0.016666666666666666,
#   'went': 0.016666666666666666,
#   'had': 0.016666666666666666,
#   'struck': 0.016666666666666666,
#   'sat': 0.016666666666666666,
#   'listened': 0.016666666666666666,
#   'pushed': 0.016666666666666666,
#   'wanted': 0.016666666666666666,
#   'heard': 0.016666666666666666,
#   'promised': 0.016666666666666666,
#   'mean': 0.016666666666666666,
#   'dont': 0.016666666666666666,
#   'verified': 0.016666666666666666,
#   'judged': 0.016666666666666666,
#   'only': 0.016666666666666666,
#   'idled': 0.016666666666666666,
#   'may': 0.016666666666666666,
#   'let': 0.016666666666666666,
#   'should': 0.016666666666666666,
#   'like': 0.016666666666666666,
#   'turned': 0.016666666666666666,
#   'often': 0.016666666666666666,
#   'name': 0.016666666666666666,
#   'stole': 0.016666666666666666,
#   'walked': 0.016666666666666666,
#   'help': 0.016666666666666666,
#   'tell': 0.016666666666666666,
#   'hate': 0.016666666666666666,
#   'blame': 0.016666666666666666,
#   'take': 0.016666666666666666,
#   'suppose': 0.016666666666666666},
#  'somewhere': {'ages': 1.0},
#  'whose': {'woods': 0.5, 'shoes': 0.5},
#  'his': {'house': 0.14285714285714285,
#   'lantern': 0.14285714285714285,
#   'wild': 0.14285714285714285,
#   'journey': 0.14285714285714285,
#   'neck': 0.14285714285714285,
#   'names': 0.14285714285714285,
#   'small': 0.14285714285714285},
#  'he': {'will': 0.034482758620689655,
#   'gives': 0.034482758620689655,
#   'saw': 0.034482758620689655,
#   'gained': 0.034482758620689655,
#   'never': 0.034482758620689655,
#   'reeled': 0.034482758620689655,
#   'fell': 0.034482758620689655,
#   'looked': 0.034482758620689655,
#   'couldnt': 0.034482758620689655,
#   'bowed': 0.034482758620689655,
#   'steered': 0.034482758620689655,
#   'want': 0.034482758620689655,
#   'stood': 0.034482758620689655,
#   'said': 0.034482758620689655,
#   'dont': 0.034482758620689655,
#   'guessed': 0.034482758620689655,
#   'read': 0.034482758620689655,
#   'broke': 0.034482758620689655,
#   'always': 0.034482758620689655,
#   'thinks': 0.034482758620689655,
#   'must': 0.034482758620689655,
#   'wont': 0.034482758620689655,
#   'cant': 0.034482758620689655,
#   'gets': 0.034482758620689655,
#   'and': 0.034482758620689655,
#   'hoed': 0.034482758620689655,
#   'knows': 0.034482758620689655,
#   'manages': 0.034482758620689655,
#   'can': 0.034482758620689655},
#  'my': {'little': 0.14285714285714285,
#   'french': 0.14285714285714285,
#   'first': 0.14285714285714285,
#   'mother': 0.14285714285714285,
#   'window': 0.14285714285714285,
#   'fingers': 0.14285714285714285,
#   'but': 0.14285714285714285},
#  'between': {'the': 0.5, 'me': 0.5},
#  'the': {'darkest': 0.012987012987012988,
#   'only': 0.012987012987012988,
#   'woods': 0.012987012987012988,
#   'headless': 0.012987012987012988,
#   'whir': 0.012987012987012988,
#   'hillside': 0.012987012987012988,
#   'swarm': 0.012987012987012988,
#   'moon': 0.012987012987012988,
#   'spell': 0.012987012987012988,
#   'thought': 0.012987012987012988,
#   'figures': 0.012987012987012988,
#   'arthur': 0.012987012987012988,
#   'tote': 0.012987012987012988,
#   'poor': 0.012987012987012988,
#   'crib': 0.012987012987012988,
#   'smarty': 0.012987012987012988,
#   'mica': 0.012987012987012988,
#   'early': 0.012987012987012988,
#   'mountain': 0.012987012987012988,
#   'old': 0.012987012987012988,
#   'two': 0.012987012987012988,
#   'outside': 0.012987012987012988,
#   'poetess': 0.012987012987012988,
#   'posies': 0.012987012987012988,
#   'attic': 0.012987012987012988,
#   'small': 0.012987012987012988,
#   'seal': 0.012987012987012988,
#   'night': 0.012987012987012988,
#   'board': 0.012987012987012988,
#   'way': 0.012987012987012988,
#   'bulkhead': 0.012987012987012988,
#   'cellar': 0.012987012987012988,
#   'door': 0.012987012987012988,
#   'faintest': 0.012987012987012988,
#   'fingerpieces': 0.012987012987012988,
#   'kitchen': 0.012987012987012988,
#   'uncommonly': 0.012987012987012988,
#   'steps': 0.012987012987012988,
#   'least': 0.012987012987012988,
#   'rural': 0.012987012987012988,
#   'west': 0.012987012987012988,
#   'breath': 0.012987012987012988,
#   'origin': 0.012987012987012988,
#   'past': 0.012987012987012988,
#   'young': 0.012987012987012988,
#   'second': 0.012987012987012988,
#   'town': 0.012987012987012988,
#   'situation': 0.012987012987012988,
#   'sound': 0.012987012987012988,
#   'indians': 0.012987012987012988,
#   'nose': 0.012987012987012988,
#   'meaning': 0.012987012987012988,
#   'voices': 0.012987012987012988,
#   'life': 0.012987012987012988,
#   'hours': 0.012987012987012988,
#   'road': 0.012987012987012988,
#   'ledges': 0.012987012987012988,
#   'chisel': 0.012987012987012988,
#   'height': 0.012987012987012988,
#   'playthings': 0.012987012987012988,
#   'sun': 0.012987012987012988,
#   'frogs': 0.012987012987012988,
#   'minute': 0.012987012987012988,
#   'same': 0.012987012987012988,
#   'snow': 0.012987012987012988,
#   'tower': 0.012987012987012988,
#   'sigmas': 0.012987012987012988,
#   'cosmic': 0.012987012987012988,
#   'utmost': 0.012987012987012988,
#   'surest': 0.012987012987012988,
#   'strains': 0.012987012987012988,
#   'rights': 0.012987012987012988,
#   'smell': 0.012987012987012988,
#   'little': 0.012987012987012988,
#   'upper': 0.012987012987012988,
#   'crystal': 0.012987012987012988,
#   'man': 0.012987012987012988},
#  'of': {'easy': 0.043478260869565216,
#   'the': 0.043478260869565216,
#   'wire': 0.043478260869565216,
#   'getting': 0.043478260869565216,
#   'arthur': 0.043478260869565216,
#   'having': 0.043478260869565216,
#   'door': 0.043478260869565216,
#   'his': 0.043478260869565216,
#   'what': 0.043478260869565216,
#   'here': 0.043478260869565216,
#   'stranger': 0.043478260869565216,
#   'an': 0.043478260869565216,
#   'castles': 0.043478260869565216,
#   'youthful': 0.043478260869565216,
#   'detail': 0.043478260869565216,
#   'being': 0.043478260869565216,
#   'country': 0.043478260869565216,
#   'dust': 0.043478260869565216,
#   'earthly': 0.043478260869565216,
#   'constellations': 0.043478260869565216,
#   'yawning': 0.043478260869565216,
#   'once': 0.043478260869565216,
#   'both': 0.043478260869565216},
#  'but': {'i': 0.02857142857142857,
#   'if': 0.02857142857142857,
#   'only': 0.02857142857142857,
#   'not': 0.02857142857142857,
#   'a': 0.02857142857142857,
#   'though': 0.02857142857142857,
#   'saved': 0.02857142857142857,
#   'now': 0.02857142857142857,
#   'most': 0.02857142857142857,
#   'everybody': 0.02857142857142857,
#   'smith': 0.02857142857142857,
#   'you': 0.02857142857142857,
#   'welcomed': 0.02857142857142857,
#   'all': 0.02857142857142857,
#   'it': 0.02857142857142857,
#   'we': 0.02857142857142857,
#   'wont': 0.02857142857142857,
#   'left': 0.02857142857142857,
#   'tonight': 0.02857142857142857,
#   'rain': 0.02857142857142857,
#   'the': 0.02857142857142857,
#   'wait': 0.02857142857142857,
#   'why': 0.02857142857142857,
#   'theres': 0.02857142857142857,
#   'dont': 0.02857142857142857,
#   'please': 0.02857142857142857,
#   'me': 0.02857142857142857,
#   'where': 0.02857142857142857,
#   'get': 0.02857142857142857,
#   'feared': 0.02857142857142857,
#   'being': 0.02857142857142857,
#   'when': 0.02857142857142857,
#   'estelle': 0.02857142857142857,
#   'its': 0.02857142857142857,
#   'whats': 0.02857142857142857},
#  'some': {'say': 0.25, 'cried': 0.25, 'zealous': 0.25, 'shattered': 0.25},
#  'from': {'what': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'that': 0.14285714285714285,
#   'my': 0.14285714285714285,
#   'north': 0.14285714285714285,
#   'stumps': 0.14285714285714285,
#   'sleeping': 0.14285714285714285},
#  'is': {'also': 0.2, 'sadder': 0.2, 'back': 0.2, 'supposed': 0.2, 'this': 0.2},
#  'natures': {'first': 1.0},
#  'her': {'hardest': 0.5, 'early': 0.5},
#  'so': {'eden': 0.09090909090909091,
#   'dawn': 0.09090909090909091,
#   'halfway': 0.09090909090909091,
#   'now': 0.09090909090909091,
#   'they': 0.09090909090909091,
#   'as': 0.09090909090909091,
#   'suddenly': 0.09090909090909091,
#   'that': 0.09090909090909091,
#   'lying': 0.09090909090909091,
#   'cant': 0.09090909090909091,
#   'near': 0.09090909090909091},
#  'nothing': {'gold': 0.5, 'would': 0.5},
#  'when': {'far': 0.16666666666666666,
#   'i': 0.16666666666666666,
#   'the': 0.16666666666666666,
#   'there': 0.16666666666666666,
#   'shoeing': 0.16666666666666666,
#   'all': 0.16666666666666666},
#  'came': {'over': 1.0},
#  'one': {'luminary': 0.1111111111111111,
#   'lizard': 0.1111111111111111,
#   'of': 0.1111111111111111,
#   'and': 0.1111111111111111,
#   'ought': 0.1111111111111111,
#   'mustnt': 0.1111111111111111,
#   'down': 0.1111111111111111,
#   'thing': 0.1111111111111111,
#   'level': 0.1111111111111111},
#  'proclaimed': {'the': 1.0},
#  'smoothlaid': {'like': 1.0},
#  'half': {'closes': 0.3333333333333333,
#   'looking': 0.3333333333333333,
#   'of': 0.3333333333333333},
#  'up': {'from': 0.16666666666666666,
#   'at': 0.16666666666666666,
#   'where': 0.16666666666666666,
#   'attic': 0.16666666666666666,
#   'one': 0.16666666666666666,
#   'to': 0.16666666666666666},
#  'a': {'tree': 0.034482758620689655,
#   'voice': 0.034482758620689655,
#   'swamp': 0.034482758620689655,
#   'barkless': 0.034482758620689655,
#   'hole': 0.034482758620689655,
#   'leak': 0.034482758620689655,
#   'cliff': 0.034482758620689655,
#   'likeness': 0.034482758620689655,
#   'whole': 0.034482758620689655,
#   'small': 0.034482758620689655,
#   'moment': 0.034482758620689655,
#   'bird': 0.034482758620689655,
#   'single': 0.034482758620689655,
#   'brush': 0.034482758620689655,
#   'piercing': 0.034482758620689655,
#   'governor': 0.034482758620689655,
#   'rockstrewn': 0.034482758620689655,
#   'bead': 0.034482758620689655,
#   'little': 0.034482758620689655,
#   'shelfs': 0.034482758620689655,
#   'chimney': 0.034482758620689655,
#   'few': 0.034482758620689655,
#   'brook': 0.034482758620689655,
#   'broken': 0.034482758620689655,
#   'note': 0.034482758620689655,
#   'friend': 0.034482758620689655,
#   'bill': 0.034482758620689655,
#   'winter': 0.034482758620689655,
#   'featherhammer': 0.034482758620689655},
#  'disturbed': {'i': 0.5, 'the': 0.5},
#  'comes': {'softly': 1.0},
#  'by': {'picking': 0.09090909090909091,
#   'doubling': 0.09090909090909091,
#   'all': 0.09090909090909091,
#   'its': 0.09090909090909091,
#   'road': 0.09090909090909091,
#   'having': 0.09090909090909091,
#   'being': 0.09090909090909091,
#   'flying': 0.09090909090909091,
#   'a': 0.09090909090909091,
#   'now': 0.09090909090909091,
#   'tying': 0.09090909090909091},
#  'if': {'all': 0.1111111111111111,
#   'i': 0.1111111111111111,
#   'some': 0.1111111111111111,
#   'anyone': 0.1111111111111111,
#   'you': 0.1111111111111111,
#   'seen': 0.1111111111111111,
#   'the': 0.1111111111111111,
#   'he': 0.1111111111111111,
#   'hes': 0.1111111111111111},
#  'were': {'not': 1.0},
#  'ten': {'million': 1.0},
#  'as': {'often': 0.08333333333333333,
#   'if': 0.08333333333333333,
#   'standing': 0.08333333333333333,
#   'long': 0.08333333333333333,
#   'we': 0.08333333333333333,
#   'gilt': 0.08333333333333333,
#   'one': 0.08333333333333333,
#   'pale': 0.08333333333333333,
#   'for': 0.08333333333333333,
#   'winds': 0.08333333333333333,
#   'married': 0.08333333333333333,
#   'near': 0.08333333333333333},
#  'it': {'looks': 0.0625,
#   'takes': 0.0625,
#   'must': 0.0625,
#   'want': 0.0625,
#   'doesnt': 0.0625,
#   'wasnt': 0.0625,
#   'was': 0.0625,
#   'took': 0.0625,
#   'ought': 0.0625,
#   'rests': 0.0625,
#   'has': 0.0625,
#   'in': 0.0625,
#   'will': 0.0625,
#   'seems': 0.0625,
#   'makes': 0.0625,
#   'lifts': 0.0625},
#  'lifted': {'the': 1.0},
#  'she': {'has': 0.06666666666666667,
#   'thinks': 0.06666666666666667,
#   'might': 0.06666666666666667,
#   'never': 0.06666666666666667,
#   'was': 0.06666666666666667,
#   'could': 0.06666666666666667,
#   'hadnt': 0.06666666666666667,
#   'swept': 0.06666666666666667,
#   'made': 0.06666666666666667,
#   'should': 0.06666666666666667,
#   'does': 0.06666666666666667,
#   'seems': 0.06666666666666667,
#   'wants': 0.06666666666666667,
#   'wont': 0.06666666666666667,
#   'raised': 0.06666666666666667},
#  'transfixed': {'on': 1.0},
#  'across': {'each': 1.0},
#  'was': {'wrought': 0.1111111111111111,
#   'arthur': 0.1111111111111111,
#   'singing': 0.1111111111111111,
#   'only': 0.1111111111111111,
#   'a': 0.1111111111111111,
#   'something': 0.1111111111111111,
#   'hot': 0.1111111111111111,
#   'counting': 0.1111111111111111,
#   'it': 0.1111111111111111},
#  'once': {'on': 0.5, 'more': 0.5},
#  'that': {'had': 0.037037037037037035,
#   'everyone': 0.037037037037037035,
#   'cased': 0.037037037037037035,
#   'is': 0.037037037037037035,
#   'even': 0.037037037037037035,
#   'as': 0.037037037037037035,
#   'they': 0.037037037037037035,
#   'was': 0.037037037037037035,
#   'happens': 0.037037037037037035,
#   'overflowing': 0.037037037037037035,
#   'doesnt': 0.037037037037037035,
#   'need': 0.037037037037037035,
#   'theres': 0.037037037037037035,
#   'made': 0.037037037037037035,
#   'now': 0.037037037037037035,
#   'turned': 0.037037037037037035,
#   'the': 0.037037037037037035,
#   'a': 0.037037037037037035,
#   'you': 0.037037037037037035,
#   'there': 0.037037037037037035,
#   'are': 0.037037037037037035,
#   'no': 0.037037037037037035,
#   'braced': 0.037037037037037035,
#   'sends': 0.037037037037037035,
#   'struck': 0.037037037037037035,
#   'much': 0.037037037037037035,
#   'isnt': 0.037037037037037035},
#  'looked': {'up': 1.0},
#  'stood': {'over': 1.0},
#  'you': {'here': 0.038461538461538464,
#   'can': 0.038461538461538464,
#   'said': 0.038461538461538464,
#   'wont': 0.038461538461538464,
#   'mean': 0.038461538461538464,
#   'dont': 0.038461538461538464,
#   'must': 0.038461538461538464,
#   'and': 0.038461538461538464,
#   'know': 0.038461538461538464,
#   'riddle': 0.038461538461538464,
#   'take': 0.038461538461538464,
#   'look': 0.038461538461538464,
#   'never': 0.038461538461538464,
#   'poor': 0.038461538461538464,
#   'will': 0.038461538461538464,
#   'want': 0.038461538461538464,
#   'see': 0.038461538461538464,
#   'seem': 0.038461538461538464,
#   'think': 0.038461538461538464,
#   'let': 0.038461538461538464,
#   'couldnt': 0.038461538461538464,
#   'cant': 0.038461538461538464,
#   'say': 0.038461538461538464,
#   'spoke': 0.038461538461538464,
#   'ought': 0.038461538461538464,
#   'neednt': 0.038461538461538464},
#  'me': {'im': 1.0},
#  'sometimes': {'i': 0.3333333333333333,
#   'he': 0.3333333333333333,
#   'as': 0.3333333333333333},
#  'brown': {'lived': 0.5, 'makes': 0.5},
#  'cross': {'lots': 1.0},
#  'describing': {'rings': 1.0},
#  'got': {'him': 1.0},
#  'walls': {'were': 1.0},
#  'like': {'wings': 0.14285714285714285,
#   'no': 0.14285714285714285,
#   'a': 0.14285714285714285,
#   'wild': 0.14285714285714285,
#   'profanation': 0.14285714285714285,
#   'graveyard': 0.14285714285714285,
#   'some': 0.14285714285714285},
#  'upon': {'his': 0.5, 'a': 0.5},
#  'with': {'no': 0.07142857142857142,
#   'all': 0.07142857142857142,
#   'stone': 0.07142857142857142,
#   'furs': 0.07142857142857142,
#   'the': 0.07142857142857142,
#   'our': 0.07142857142857142,
#   'sounds': 0.07142857142857142,
#   'clouds': 0.07142857142857142,
#   'a': 0.07142857142857142,
#   'his': 0.07142857142857142,
#   'flowers': 0.07142857142857142,
#   'half': 0.07142857142857142,
#   'whose': 0.07142857142857142,
#   'me': 0.07142857142857142},
#  'faster': {'or': 1.0},
#  'sitting': {'or': 1.0},
#  'according': {'as': 1.0},
#  'hes': {'celebrating': 0.09090909090909091,
#   'so': 0.09090909090909091,
#   'after': 0.09090909090909091,
#   'groping': 0.09090909090909091,
#   'nothing': 0.09090909090909091,
#   'just': 0.09090909090909091,
#   'got': 0.09090909090909091,
#   'fiftyfive': 0.09090909090909091,
#   'given': 0.09090909090909091,
#   'fond': 0.09090909090909091,
#   'been': 0.09090909090909091},
#  'or': {'been': 0.09090909090909091,
#   'even': 0.09090909090909091,
#   'stained': 0.09090909090909091,
#   'like': 0.09090909090909091,
#   'else': 0.09090909090909091,
#   'a': 0.09090909090909091,
#   'i': 0.09090909090909091,
#   'it': 0.09090909090909091,
#   'creaking': 0.09090909090909091,
#   'some': 0.09090909090909091,
#   'old': 0.09090909090909091},
#  'incredulous': {'of': 1.0},
#  'well—i—be—': {'that': 1.0},
#  'on': {'motorcars': 0.09090909090909091,
#   'moosilauke': 0.09090909090909091,
#   'slippery': 0.09090909090909091,
#   'marshall': 0.09090909090909091,
#   'an': 0.09090909090909091,
#   'fathers': 0.09090909090909091,
#   'last': 0.09090909090909091,
#   'planets': 0.09090909090909091,
#   'his': 0.09090909090909091,
#   'something': 0.09090909090909091,
#   'some': 0.09090909090909091},
#  'should': {'say': 0.5, 'take': 0.5},
#  'yankees': {'are': 1.0},
#  'dont': {'think': 0.14285714285714285,
#   'donkeys': 0.14285714285714285,
#   'ask': 0.14285714285714285,
#   'make': 0.14285714285714285,
#   'be': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'build': 0.14285714285714285},
#  'until': {'the': 0.5, 'id': 0.5},
#  'after': {'the': 1.0},
#  'not': {'much': 0.09090909090909091,
#   'that': 0.09090909090909091,
#   'so': 0.09090909090909091,
#   'like': 0.09090909090909091,
#   'from': 0.09090909090909091,
#   'fireweed': 0.09090909090909091,
#   'bluebells': 0.09090909090909091,
#   'lupine': 0.09090909090909091,
#   'in': 0.09090909090909091,
#   'to': 0.09090909090909091,
#   'answering': 0.09090909090909091},
#  'at': {'that': 0.25, 'having': 0.25, 'least': 0.25, 'ten': 0.25},
#  'no': {'more': 0.1111111111111111,
#   'doubt': 0.1111111111111111,
#   'bird': 0.1111111111111111,
#   'fête': 0.1111111111111111,
#   'its': 0.1111111111111111,
#   'one': 0.1111111111111111,
#   'i': 0.1111111111111111,
#   'matter': 0.1111111111111111,
#   'he': 0.1111111111111111},
#  'ive': {'kept': 0.25, 'never': 0.25, 'been': 0.25, 'got': 0.25},
#  'while': {'i': 1.0},
#  'bout': {'out': 1.0},
#  'now': {'that': 0.25, 'give': 0.25, 'lefts': 0.25, 'slowly': 0.25},
#  'im': {'going': 0.2,
#   'stark': 0.2,
#   'waiting': 0.2,
#   'getting': 0.2,
#   'sure': 0.2},
#  'theyve': {'got': 1.0},
#  'flattered': {'i': 1.0},
#  'they': {'dont': 0.07142857142857142,
#   'set': 0.07142857142857142,
#   'made': 0.07142857142857142,
#   'found': 0.07142857142857142,
#   'bad': 0.07142857142857142,
#   'simply': 0.07142857142857142,
#   'were': 0.07142857142857142,
#   'have': 0.07142857142857142,
#   'eddy': 0.07142857142857142,
#   'think': 0.07142857142857142,
#   'might': 0.07142857142857142,
#   'spoke': 0.07142857142857142,
#   'left': 0.07142857142857142,
#   'filled': 0.07142857142857142},
#  'always': {'the': 1.0},
#  'ill': {'double': 0.14285714285714285,
#   'tell': 0.14285714285714285,
#   'find': 0.14285714285714285,
#   'show': 0.14285714285714285,
#   'hardly': 0.14285714285714285,
#   'say': 0.14285714285714285,
#   'talk': 0.14285714285714285},
#  'theyll': {'find': 1.0},
#  'for': {'hog': 0.16666666666666666,
#   'gods': 0.16666666666666666,
#   'a': 0.16666666666666666,
#   'god': 0.16666666666666666,
#   'helping': 0.16666666666666666,
#   'fifty': 0.16666666666666666},
#  'couldnt': {'have': 0.5, 'one': 0.5},
#  'voted': {'the': 1.0},
#  'which': {'wasnt': 0.3333333333333333,
#   'means': 0.3333333333333333,
#   'is': 0.3333333333333333},
#  'their': {'arthur': 0.5, 'solemn': 0.5},
#  'wentworth': {'and': 1.0},
#  'only': {'i': 0.2, 'bewitched': 0.2, 'to': 0.2, 'one': 0.2, 'too': 0.2},
#  'rights': {'right': 1.0},
#  'has': {'always': 0.5, 'been': 0.5},
#  'itd': {'make': 1.0},
#  'said': {'that': 1.0},
#  'hed': {'bet': 0.25, 'like': 0.25, 'say': 0.25, 'need': 0.25},
#  'all': {'four': 0.14285714285714285,
#   'is': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'claiming': 0.14285714285714285,
#   'fresh': 0.14285714285714285,
#   'that': 0.14285714285714285,
#   'we': 0.14285714285714285},
#  'gnaws': {'in': 1.0},
#  'last': {'night': 1.0},
#  'over': {'the': 0.25, 'so': 0.25, 'descended': 0.25, 'back': 0.25},
#  'well': {'i': 0.25, 'take': 0.25, 'if': 0.25, 'then': 0.25},
#  'off': {'from': 0.5, 'here': 0.5},
#  'old': {'davis': 0.5, 'as': 0.5},
#  'thered': {'been': 1.0},
#  'someday': {'i': 1.0},
#  'huh': {'that': 1.0},
#  'lets': {'talk': 0.3333333333333333,
#   'go': 0.3333333333333333,
#   'trap': 0.3333333333333333},
#  'youve': {'lost': 1.0},
#  'can': {'do': 1.0},
#  'be': {'dragged': 0.3333333333333333,
#   'ready': 0.3333333333333333,
#   'good': 0.3333333333333333},
#  'we': {'made': 0.09090909090909091,
#   'came': 0.09090909090909091,
#   'may': 0.09090909090909091,
#   'struck': 0.09090909090909091,
#   'trod': 0.09090909090909091,
#   'were': 0.09090909090909091,
#   'have': 0.09090909090909091,
#   'know': 0.09090909090909091,
#   'can': 0.09090909090909091,
#   'wouldnt': 0.09090909090909091,
#   'fence': 0.09090909090909091},
#  'ascending': {'to': 1.0},
#  'sos': {'everything': 0.5, 'to': 0.5},
#  'hadnt': {'you': 1.0},
#  'look': {'here': 1.0},
#  'what': {'signify': 0.1,
#   'it': 0.1,
#   'bones': 0.1,
#   'do': 0.1,
#   'i': 0.1,
#   'is': 0.1,
#   'he': 0.1,
#   'childishness': 0.1,
#   'are': 0.1,
#   'well': 0.1},
#  'however': {'natural': 0.5, 'far': 0.5},
#  'come': {'straight': 0.25, 'down': 0.25, 'here': 0.25, 'out': 0.25},
#  'its': {'hell': 0.05555555555555555,
#   'not': 0.05555555555555555,
#   'sometimes': 0.05555555555555555,
#   'the': 0.05555555555555555,
#   'to': 0.05555555555555555,
#   'harmless': 0.05555555555555555,
#   'coming': 0.05555555555555555,
#   'with': 0.05555555555555555,
#   'looking': 0.05555555555555555,
#   'raining': 0.05555555555555555,
#   'as': 0.05555555555555555,
#   'going': 0.05555555555555555,
#   'hands': 0.05555555555555555,
#   'whirling': 0.05555555555555555,
#   'you': 0.05555555555555555,
#   'gone': 0.05555555555555555,
#   'too': 0.05555555555555555,
#   'different': 0.05555555555555555},
#  'perhaps': {'to': 0.5, 'you': 0.5},
#  'excuse': {'me': 1.0},
#  'who': {'used': 0.16666666666666666,
#   'failed': 0.16666666666666666,
#   'only': 0.16666666666666666,
#   'may': 0.16666666666666666,
#   'are': 0.16666666666666666,
#   'wants': 0.16666666666666666},
#  'life': {'long': 1.0},
#  'our': {'business': 0.5, 'hens': 0.5},
#  'through': {'a': 0.5, 'everything': 0.5},
#  'except': {'it': 0.5, 'always': 0.5},
#  'books': {'i': 0.5, 'were': 0.5},
#  'where': {'driven': 0.125,
#   'did': 0.125,
#   'shall': 0.125,
#   'the': 0.125,
#   'were': 0.125,
#   'is': 0.125,
#   'conies': 0.125,
#   'he': 0.125},
#  'enough': {'to': 1.0},
#  'unfortunately': {'all': 1.0},
#  'boys': {'and': 1.0},
#  'shatter': {'it': 1.0},
#  'how': {'had': 0.2, 'could': 0.2, 'shall': 0.2, 'do': 0.2, 'are': 0.2},
#  'till': {'it': 0.5, 'well': 0.5},
#  'tried': {'to': 1.0},
#  'having': {'tried': 1.0},
#  'here': {'were': 0.25, 'are': 0.25, 'he': 0.25, 'loveless': 0.25},
#  'take': {'one': 0.3333333333333333,
#   'all': 0.3333333333333333,
#   'it': 0.3333333333333333},
#  'why': {'not': 0.5, 'do': 0.5},
#  'goodlooking': {'books': 1.0},
#  'both': {'either': 1.0},
#  'legitimately': {'my': 1.0},
#  'there': {'wasnt': 0.25, 'aint': 0.25, 'is': 0.25, 'was': 0.25},
#  'alias': {'john': 1.0},
#  'about': {'where': 1.0},
#  'theres': {'not': 1.0},
#  'give': {'a': 1.0},
#  'thrown': {'away': 1.0},
#  'unless': {'it': 1.0},
#  'than': {'lifes': 0.5, 'folks': 0.5},
#  'behind': {'the': 1.0},
#  'mother': {'folks': 0.14285714285714285,
#   'and': 0.14285714285714285,
#   'bones': 0.14285714285714285,
#   'well': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'we': 0.14285714285714285,
#   'yes': 0.14285714285714285},
#  'summoning': {'spirits': 1.0},
#  'whos': {'got': 1.0},
#  'son': {'mother': 0.14285714285714285,
#   'you': 0.14285714285714285,
#   'but': 0.14285714285714285,
#   'it': 0.14285714285714285,
#   'we': 0.14285714285714285,
#   'knows': 0.14285714285714285,
#   'looks': 0.14285714285714285},
#  'rather': {'than': 1.0},
#  'tell': {'you': 0.5, 'me': 0.5},
#  'yes': {'theres': 0.125,
#   'stark': 0.125,
#   'what': 0.125,
#   'its': 0.125,
#   'you': 0.125,
#   'whats': 0.125,
#   'but': 0.125,
#   'i': 0.125},
#  'against': {'the': 1.0},
#  'halting': {'perplexed': 1.0},
#  'another': {'from': 1.0},
#  'right': {'past': 1.0},
#  'father': {'had': 1.0},
#  'especially': {'in': 1.0},
#  'might': {'just': 1.0},
#  'toffile': {'had': 0.2, 'for': 0.2, 'agreed': 0.2, 'get': 0.2, 'if': 0.2},
#  'struck': {'the': 1.0},
#  'began': {'the': 1.0},
#  'waiting': {'for': 1.0},
#  'flashed': {'out': 1.0},
#  'smoke': {'rolled': 1.0},
#  'hand': {'me': 1.0},
#  'stillgoing': {'every': 1.0},
#  'before': {'i': 0.5, 'its': 0.5},
#  'almost': {'the': 1.0},
#  'quick': {'i': 1.0},
#  'let': {'them': 0.5, 'people': 0.5},
#  'brushing': {'their': 1.0},
#  'thats': {'what': 0.25, 'a': 0.25, 'no': 0.25, 'his': 0.25},
#  '2o3': {'let': 1.0},
#  'wed': {'kept': 1.0},
#  'could': {'tell': 1.0},
#  'among': {'the': 0.5, 'unearthed': 0.5},
#  'ancestral': {'memories': 1.0},
#  'someone': {'had': 1.0},
#  'thence': {'they': 1.0},
#  'made': {'shift': 1.0},
#  'are': {'there': 1.0},
#  'strolled': {'thither': 1.0},
#  'anyone': {'else': 0.5, 'upon': 0.5},
#  'this': {'was': 0.25, 'he': 0.25, 'is': 0.25, 'eden': 0.25},
#  'provision': {'there': 1.0},
#  'drawn': {'on': 0.5, 'into': 0.5},
#  'stark': {'he': 1.0},
#  'would': {'have': 0.5, 'name': 0.5},
#  'several': {'times': 1.0},
#  'under': {'the': 0.5, 'a': 0.5},
#  'just': {'so': 1.0},
#  'does': {'the': 0.5, 'it': 0.5},
#  'bowed': {'outward': 1.0},
#  'beyond': {'where': 0.5, 'which': 0.5},
#  'four': {'cards': 1.0},
#  'dyou': {'know': 1.0},
#  'studying': {'genealogy': 1.0},
#  'first': {'let': 0.5, 'theres': 0.5},
#  'bless': {'you': 1.0},
#  'shes': {'after': 0.3333333333333333,
#   'in': 0.3333333333333333,
#   'let': 0.3333333333333333},
#  'heres': {'hoping': 1.0},
#  'making': {'allowance': 1.0},
#  'see': {'that': 1.0},
#  'strung': {'on': 1.0},
#  'something': {'i': 0.5, 'went': 0.5},
#  'speaking': {'or': 1.0},
#  'strangely': {'its': 1.0},
#  'call': {'her': 1.0},
#  'nor': {'grannys': 0.25, 'never': 0.25, 'need': 0.25, 'want': 0.25},
#  'nine': {'times': 1.0},
#  'anything': {'she': 1.0},
#  'folks': {'in': 1.0},
#  'mebbe': {'im': 1.0},
#  'more': {'of': 1.0},
#  'will': {'you': 0.5, 'leave': 0.5},
#  'nowhere': {'but': 1.0},
#  'builder': {'in': 1.0},
#  'whatever': {'they': 1.0},
#  'inscription': {'for': 1.0},
#  'winds': {'blow': 1.0},
#  'moisture': {'and': 1.0},
#  'heaven': {'gives': 1.0},
#  'back': {'out': 0.5, 'in': 0.5},
#  'may': {'seem': 1.0},
#  'great': {'monolithic': 1.0},
#  'long': {'since': 1.0},
#  'besides': {'the': 1.0},
#  'still': {'said': 0.5, 'more': 0.5},
#  'charge': {'that': 1.0},
#  'make': {'yourself': 0.5, 'so': 0.5},
#  'someones': {'road': 1.0},
#  'into': {'each': 1.0},
#  'weep': {'for': 1.0},
#  'your': {'destination': 1.0},
#  'cold': {'as': 1.0},
#  'too': {'lofty': 0.5, 'late': 0.5},
#  'drink': {'and': 1.0},
#  'wherever': {'the': 1.0},
#  'birch': {'boughs': 1.0},
#  'time': {'someone': 1.0},
#  'small': {'good': 1.0},
#  'out': {'in': 1.0},
#  'awake': {'that': 1.0},
#  'wishing': {'that': 1.0},
#  'saturn': {'and': 1.0},
#  'theirs': {'interlock': 1.0},
#  'uttered': {'alone': 1.0},
#  'trembled': {'and': 1.0},
#  'appear': {'like': 1.0},
#  'around': {'and': 1.0},
#  'since': {'man': 1.0},
#  'lord': {'if': 1.0},
#  'havent': {'you': 0.5, 'as': 0.5},
#  'whats': {'wanted': 0.3333333333333333,
#   'this': 0.3333333333333333,
#   'the': 0.3333333333333333},
#  'estelles': {'to': 0.5, 'the': 0.5},
#  'weve': {'been': 1.0},
#  'left': {'here': 1.0},
#  'hell': {'sort': 1.0},
#  'skyhigh': {'with': 1.0},
#  'arent': {'you': 1.0},
#  'john': {'hall': 0.16666666666666666,
#   'likes': 0.16666666666666666,
#   'bought': 0.16666666666666666,
#   'said': 0.16666666666666666,
#   'himself': 0.16666666666666666,
#   'threw': 0.16666666666666666},
#  'better': {'than': 1.0},
#  'reason': {'enough': 1.0},
#  'such': {'as': 1.0},
#  'twas': {'we': 1.0},
#  'johns': {'a': 0.5, 'almost': 0.5},
#  'estelle': {'to': 1.0},
#  'farmers': {'around': 1.0},
#  'full': {'of': 1.0},
#  'moving': {'a': 1.0},
#  'nothings': {'too': 1.0},
#  'twenty': {'for': 1.0},
#  'receipted': {'and': 1.0},
#  'wampum': {'i': 1.0},
#  'cant': {'you': 1.0},
#  'being': {'cut': 1.0},
#  'oho': {'oho': 1.0},
#  'bad': {'to': 1.0},
#  'nonsense': {'see': 1.0},
#  'whod': {'marry': 1.0},
#  'say': {'it': 1.0},
#  'youll': {'be': 1.0},
#  'coming': {'down': 1.0},
#  'isnt': {'it': 1.0},
#  'do': {'go': 1.0},
#  'content': {'with': 1.0},
#  'an': {'hour': 1.0}}

# %%
for k, ts in second_order.items():
  second_order[k] = list2pdict(ts)

# %%
def sample_word(d):
  # print "d:", d
  p0 = np.random.random()
  # print "p0:", p0
  cumulative = 0
  for t, p in d.items():
    cumulative += p
    if p0 < cumulative:
      return t
  assert(False) # should never get here

# %%
def generate():
  for i in range(4): # generate 4 lines
    sentence = []

    # initial word
    w0 = sample_word(initial)
    sentence.append(w0)

    # sample second word
    w1 = sample_word(first_order[w0])
    sentence.append(w1)

    # second-order transitions until END
    while True:
      w2 = sample_word(second_order[(w0, w1)])
      if w2 == 'END':
        break
      sentence.append(w2)
      w0 = w1
      w1 = w2
    print(' '.join(sentence))

# %%
generate()
# Out:
# and stamped and said things to happen in their town a noted witch
# but why take time for what im like to take it what was his was always hers
# you take the timber
# unfortunately all of one kind though
